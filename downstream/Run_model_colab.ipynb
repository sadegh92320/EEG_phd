# %%
print("Hello from Colab in VS Code!")
# Out:
# Hello from Colab in VS Code!

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import sys
sys.path.append('/content/drive/MyDrive/my_project')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-752812196.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive', force_remount=True)
#       3
#       4 import sys
#       5 sys.path.append('/content/drive/MyDrive/my_project')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
# ...

# %%
from downstream.pipeline import Pipeline
from process_data.mne_constructor import MNEMethods
import yaml
from dataset import EEGdataset
from downstream.training_model import TrainerDownstream
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3829526650.py in <cell line: 0>()
# ----> 1 from pipeline import Pipeline
#       2 from process_data.mne_constructor import MNEMethods
#       3 import yaml
#       4 from dataset import EEGdataset
#       5 from downstream.training_model import TrainerDownstream
#
# ModuleNotFoundError: No module named 'pipeline'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
with open("setting.yaml") as f:
        config = yaml.safe_load(f)

pipeline = Pipeline(dataimporter = None, dataset=EEGdataset, trainer = TrainerDownstream, config=config)
pipeline.import_data()
pipeline.train_model()
